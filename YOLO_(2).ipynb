# %% [markdown]
# <a href="https://colab.research.google.com/github/jeyakhan064/Giki_Faculty_Lounge_Object_Detection/blob/main/YOLO_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/Javeria
# Out:
# /content/Javeria

# %%
# !unzip /content/Giki.v1-roboflow-instant-1--eval-.yolov11.zip
# Out:
# Archive:  /content/Giki.v1-roboflow-instant-1--eval-.yolov11.zip
# replace README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Load a COCO-pretrained YOLO12s model
model = YOLO("yolo11n.pt")

# %%
# %cd /content/Javeria
# Out:
# /content/Javeria

# %%
# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="/content/Javeria/data.yaml", epochs=500, imgsz=640, name='Giki_Faculty_Cafe')
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# #### Inference on image

# %%
# Function for inference on a single image

def infer_image(image_path, output_path="/content/WhatsApp Image 2025-08-10 at 2.00.00 PM.jpeg"):
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Could not load image at {image_path}")
        return

    # Perform inference
    results = model(img)

    # Draw bounding boxes and labels on the image
    annotated_img = results[0].plot()

    # Save the output image
    # cv2.imwrite(output_path, annotated_img)
    cv2_imshow(annotated_img)
    print(f"Output image saved at {output_path}")

# %%
image_path = "/content/WhatsApp Image 2025-08-10 at 2.00.00 PM.jpeg"

# %%
# Run inference on image
infer_image(image_path, "/content/WhatsApp Image 2025-08-10 at 2.00.00 PM.jpeg")
# Out:
# 0: 512x640 11 Chairs, 48.4ms
# Speed: 3.7ms preprocess, 48.4ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
# <PIL.Image.Image image mode=RGB size=1280x963>
# Output image saved at /content/WhatsApp Image 2025-08-10 at 2.00.00 PM.jpeg

# %% [markdown]
# ### Inferencing on video

# %%
# Function for inference on a video
def infer_video(video_path, output_path="/content/WhatsApp Video 2025-08-10 at 1.59.59 PM.mp4"):
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video at {video_path}")
        return

    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    # Process video frame by frame
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform inference on the frame
        results = model(frame)

        # Draw bounding boxes and labels on the frame
        annotated_frame = results[0].plot()

        # Write the frame to the output video
        out.write(annotated_frame)

    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Output video saved at {output_path}")

# %%
# Run inference on image
video_path = "/content/WhatsApp Video 2025-08-10 at 1.59.59 PM.mp4"

# %%
# Run inference on video
infer_video(video_path, "/content/WhatsApp Video 2025-08-10 at 1.59.59 PM.mp4")
# Out:
# 0: 384x640 3 Chairs, 13.1ms
# Speed: 2.6ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Chairs, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Chairs, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Chairs, 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Chairs, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Chairs, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Chairs, 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Chairs, 9.9ms
# ...

# %%
import cv2

def infer_video(video_path, output_path="/content/WhatsApp Video 2025-08-10 at 1.59.59 PM (2).mp4"):
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video at {video_path}")
        return

    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    # Process video frame by frame
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform inference on the frame
        results = model(frame)

        # Get the annotated frame (with bounding boxes)
        annotated_frame = results[0].plot()

        # Access detection results (boxes, scores, and classes)
        detections = results[0].boxes  # Assuming YOLO-like model output
        for box in detections:
            # Extract coordinates, confidence, and class ID
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)  # Bounding box coordinates
            conf = box.conf[0].cpu().numpy()  # Confidence score
            cls = int(box.cls[0].cpu().numpy())  # Class ID
            label = f"{model.names[cls]} {conf:.2f}"  # Class name and confidence score

            # Define text properties
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 0.5
            color = (255, 255, 255)  # White text
            thickness = 1
            text_size = cv2.getTextSize(label, font, font_scale, thickness)[0]
            text_x = x1
            text_y = y1 - 10 if y1 - 10 > 10 else y1 + 10  # Place text above or below box

            # Draw text background for better visibility
            cv2.rectangle(
                annotated_frame,
                (text_x, text_y - text_size[1]),
                (text_x + text_size[0], text_y),
                (0, 0, 0),  # Black background
                cv2.FILLED,
            )

            # Draw text on the frame
            cv2.putText(
                annotated_frame,
                label,
                (text_x, text_y),
                font,
                font_scale,
                color,
                thickness,
                cv2.LINE_AA,
            )

        # Write the frame to the output video
        out.write(annotated_frame)

    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Output video saved at {output_path}")

# %%
# Run inference on video
infer_video('/content/WhatsApp Video 2025-08-10 at 1.59.59 PM.mp4', "/content/WhatsApp Video 2025-08-10 at 1.59.59 PM (2).mp4")
# Out:
# 0: 384x640 3 Chairs, 13.1ms
# Speed: 2.9ms preprocess, 13.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Chairs, 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Chairs, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Chairs, 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Chairs, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Chairs, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Chairs, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Chairs, 8.8ms
# ...

# %% [markdown]
# ### Next
#
# Task:
